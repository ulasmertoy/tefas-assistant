# %%
import pandas as pd

df = pd.read_parquet("data/processed/funds_features.parquet")

# %%
df.head()
# Out:
#                                                   title  history_days  league  \
# code
# AAL                 ATA PORTFÖY PARA PİYASASI (TL) FONU          1256  mature
# AAS                 ATA PORTFÖY FON SEPETİ SERBEST FONU          1256  mature
# AAV   ATA PORTFÖY İKİNCİ HİSSE SENEDİ (TL) FONU (HİS...          1256  mature
# AC1     PARDUS PORTFÖY KISA VADELİ KATILIM SERBEST FONU           707  mature
# AC4               PARDUS PORTFÖY PARA PİYASASI (TL) FON           754  mature
#
#       return_1y  return_2y  return_4y  return_inception  volatility    sharpe  \
# code
# AAL    0.504094   0.549557   0.424140          0.369570    0.015773  0.847252
# AAS    0.508284   0.307366   0.378603          0.286760    0.143815 -0.272185
# AAV    0.345852   0.136528   0.691497          0.691838    0.269629  0.972535
# AC1    0.466016   0.490700        NaN          0.464167    0.015394 -3.327337
# AC4    0.526396   0.561853        NaN          0.530639    0.017721  0.730948
#
# ...
